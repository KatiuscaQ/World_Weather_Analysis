# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
                
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | visby
# Processing Record 2 of Set 1 | mehran
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | dharchula
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | tuatapere
# Processing Record 13 of Set 1 | ca mau
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | kichera
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | bastia
# Processing Record 23 of Set 1 | casma
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | port augusta
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | esperance
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | pakxe
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | jawar
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | nelson bay
# Processing Record 35 of Set 1 | aklavik
# Processing Record 36 of Set 1 | sioux lookout
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | padang
# Processing Record 39 of Set 1 | kouroussa
# Processing Record 40 of Set 1 | ilulissat
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | maki
# Processing Record 46 of Set 1 | labuhan
# Processing Record 47 of Set 1 | koungheul
# Processing Record 48 of Set 1 | santa maria
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | dunedin
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | miri
# Processing Record 5 of Set 2 | pangnirtung
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | amethi
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | arlit
# Processing Record 16 of Set 2 | raudeberg
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | cozumel
# Processing Record 19 of Set 2 | sivas
# Processing Record 20 of Set 2 | moerai
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | azanka
# Processing Record 25 of Set 2 | quatre cocos
# Processing Record 26 of Set 2 | el reno
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | yar-sale
# Processing Record 30 of Set 2 | bac lieu
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | kirovsk
# Processing Record 34 of Set 2 | luganville
# Processing Record 35 of Set 2 | qasigiannguit
# Processing Record 36 of Set 2 | rio claro
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | kassala
# Processing Record 39 of Set 2 | aljezur
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | vao
# Processing Record 44 of Set 2 | sibolga
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 2 | matamoros
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | shellbrook
# Processing Record 50 of Set 2 | isangel
# Processing Record 1 of Set 3 | gat
# Processing Record 2 of Set 3 | mucuri
# Processing Record 3 of Set 3 | sao miguel do araguaia
# Processing Record 4 of Set 3 | lotung
# City not found. Skipping...
# Processing Record 5 of Set 3 | port keats
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | coahuayana
# Processing Record 9 of Set 3 | neiafu
# Processing Record 10 of Set 3 | bidhuna
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | asau
# Processing Record 15 of Set 3 | kribi
# Processing Record 16 of Set 3 | valenca
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | codrington
# Processing Record 19 of Set 3 | marsa matruh
# Processing Record 20 of Set 3 | domoni
# Processing Record 21 of Set 3 | husavik
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | grand-lahou
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | marathon
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | pljevlja
# Processing Record 29 of Set 3 | caravelas
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | gilgit
# Processing Record 32 of Set 3 | la ronge
# Processing Record 33 of Set 3 | alekseyevka
# Processing Record 34 of Set 3 | otoka
# Processing Record 35 of Set 3 | lasa
# Processing Record 36 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 3 | zhangjiakou
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | saint-augustin
# Processing Record 40 of Set 3 | basoko
# Processing Record 41 of Set 3 | barzas
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | oriximina
# Processing Record 45 of Set 3 | mount gambier
# Processing Record 46 of Set 3 | chimbote
# Processing Record 47 of Set 3 | banjar
# Processing Record 48 of Set 3 | carballo
# Processing Record 49 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 3 | necochea
# Processing Record 1 of Set 4 | baculin
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | lanzhou
# Processing Record 4 of Set 4 | namibe
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | mirabad
# Processing Record 8 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | portland
# Processing Record 10 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 4 | yaan
# Processing Record 12 of Set 4 | calog
# City not found. Skipping...
# Processing Record 13 of Set 4 | samagaltay
# Processing Record 14 of Set 4 | nouadhibou
# Processing Record 15 of Set 4 | shakawe
# Processing Record 16 of Set 4 | garwa
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 4 | baruun-urt
# Processing Record 19 of Set 4 | mawlaik
# Processing Record 20 of Set 4 | watertown
# Processing Record 21 of Set 4 | bytca
# Processing Record 22 of Set 4 | hereford
# Processing Record 23 of Set 4 | cape town
# Processing Record 24 of Set 4 | santa cruz del sur
# Processing Record 25 of Set 4 | fukue
# Processing Record 26 of Set 4 | muravlenko
# Processing Record 27 of Set 4 | turukhansk
# Processing Record 28 of Set 4 | barguzin
# Processing Record 29 of Set 4 | inirida
# Processing Record 30 of Set 4 | charters towers
# Processing Record 31 of Set 4 | batagay
# Processing Record 32 of Set 4 | bull savanna
# Processing Record 33 of Set 4 | aykhal
# Processing Record 34 of Set 4 | verkhnetulomskiy
# Processing Record 35 of Set 4 | namie
# Processing Record 36 of Set 4 | sterling
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | launceston
# Processing Record 39 of Set 4 | malpura
# Processing Record 40 of Set 4 | pahrump
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | northam
# Processing Record 45 of Set 4 | yamada
# Processing Record 46 of Set 4 | norrtalje
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | port-gentil
# Processing Record 49 of Set 4 | salinopolis
# Processing Record 50 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 5 | colac
# Processing Record 2 of Set 5 | carlsbad
# Processing Record 3 of Set 5 | pemba
# Processing Record 4 of Set 5 | darque
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 5 | san cristobal
# Processing Record 11 of Set 5 | shanghai
# Processing Record 12 of Set 5 | gryazovets
# Processing Record 13 of Set 5 | chapais
# Processing Record 14 of Set 5 | saskylakh
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | cayenne
# Processing Record 17 of Set 5 | butaritari
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | port hawkesbury
# Processing Record 22 of Set 5 | lamu
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | khatanga
# Processing Record 27 of Set 5 | xapuri
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | reyes
# Processing Record 30 of Set 5 | akyab
# Processing Record 31 of Set 5 | makokou
# Processing Record 32 of Set 5 | yeppoon
# Processing Record 33 of Set 5 | bosaso
# Processing Record 34 of Set 5 | kamenka
# Processing Record 35 of Set 5 | yala
# Processing Record 36 of Set 5 | purranque
# Processing Record 37 of Set 5 | bandarbeyla
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | buraydah
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | genhe
# Processing Record 44 of Set 5 | awjilah
# Processing Record 45 of Set 5 | bairnsdale
# Processing Record 46 of Set 5 | iquitos
# Processing Record 47 of Set 5 | thunder bay
# Processing Record 48 of Set 5 | douglas
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | guasdualito
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | xinmin
# Processing Record 3 of Set 6 | prince rupert
# Processing Record 4 of Set 6 | saint-philippe
# Processing Record 5 of Set 6 | najran
# Processing Record 6 of Set 6 | vila velha
# Processing Record 7 of Set 6 | chuy
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | sobolevo
# Processing Record 10 of Set 6 | omboue
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 6 | kalaiya
# Processing Record 13 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | paracuru
# Processing Record 15 of Set 6 | pandan
# Processing Record 16 of Set 6 | mnogovershinnyy
# Processing Record 17 of Set 6 | gedo
# Processing Record 18 of Set 6 | touros
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | airai
# Processing Record 23 of Set 6 | puerto narino
# Processing Record 24 of Set 6 | merauke
# Processing Record 25 of Set 6 | vestmanna
# Processing Record 26 of Set 6 | nyagan
# Processing Record 27 of Set 6 | nanchang
# Processing Record 28 of Set 6 | vilyuysk
# Processing Record 29 of Set 6 | sarangani
# Processing Record 30 of Set 6 | hue
# Processing Record 31 of Set 6 | tazovskiy
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | palmer
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | kayes
# Processing Record 36 of Set 6 | abha
# Processing Record 37 of Set 6 | xam nua
# Processing Record 38 of Set 6 | kang
# Processing Record 39 of Set 6 | olafsvik
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | altamira
# Processing Record 42 of Set 6 | ushtobe
# Processing Record 43 of Set 6 | ambon
# Processing Record 44 of Set 6 | wakkanai
# Processing Record 45 of Set 6 | iskateley
# Processing Record 46 of Set 6 | kupang
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | dryden
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | yulara
# Processing Record 2 of Set 7 | dera gopipur
# Processing Record 3 of Set 7 | kensington
# Processing Record 4 of Set 7 | la ligua
# Processing Record 5 of Set 7 | acapulco
# Processing Record 6 of Set 7 | morehead
# Processing Record 7 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 8 of Set 7 | homer
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 7 | aswan
# Processing Record 14 of Set 7 | antofagasta
# Processing Record 15 of Set 7 | hambantota
# Processing Record 16 of Set 7 | coihaique
# Processing Record 17 of Set 7 | halmstad
# Processing Record 18 of Set 7 | valencia
# Processing Record 19 of Set 7 | zavoronezhskoye
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | port macquarie
# Processing Record 22 of Set 7 | moussoro
# Processing Record 23 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 7 | mangrol
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | beringovskiy
# Processing Record 27 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 7 | santa isabel do rio negro
# Processing Record 29 of Set 7 | griffith
# Processing Record 30 of Set 7 | koltsovo
# Processing Record 31 of Set 7 | saldanha
# Processing Record 32 of Set 7 | wairoa
# Processing Record 33 of Set 7 | miajadas
# Processing Record 34 of Set 7 | atbasar
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | narsaq
# Processing Record 37 of Set 7 | bilma
# Processing Record 38 of Set 7 | consett
# Processing Record 39 of Set 7 | collierville
# Processing Record 40 of Set 7 | lucea
# Processing Record 41 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 42 of Set 7 | karoi
# Processing Record 43 of Set 7 | siguiri
# Processing Record 44 of Set 7 | maragogi
# Processing Record 45 of Set 7 | goundam
# Processing Record 46 of Set 7 | edmonton
# Processing Record 47 of Set 7 | makat
# Processing Record 48 of Set 7 | belmonte
# Processing Record 49 of Set 7 | innisfail
# Processing Record 50 of Set 7 | sakakah
# Processing Record 1 of Set 8 | west wendover
# Processing Record 2 of Set 8 | vallenar
# Processing Record 3 of Set 8 | paraiso
# Processing Record 4 of Set 8 | wladyslawowo
# Processing Record 5 of Set 8 | altay
# Processing Record 6 of Set 8 | chicama
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | ahipara
# Processing Record 9 of Set 8 | los amates
# Processing Record 10 of Set 8 | biltine
# Processing Record 11 of Set 8 | cherskiy
# Processing Record 12 of Set 8 | meadow lake
# Processing Record 13 of Set 8 | nuevo casas grandes
# Processing Record 14 of Set 8 | jalalpur pirwala
# Processing Record 15 of Set 8 | altamont
# Processing Record 16 of Set 8 | bullas
# Processing Record 17 of Set 8 | barkot
# Processing Record 18 of Set 8 | santa cruz
# Processing Record 19 of Set 8 | tortoli
# Processing Record 20 of Set 8 | kalabo
# Processing Record 21 of Set 8 | kushiro
# Processing Record 22 of Set 8 | alamor
# Processing Record 23 of Set 8 | kuandian
# Processing Record 24 of Set 8 | saryozek
# Processing Record 25 of Set 8 | hofn
# Processing Record 26 of Set 8 | chebenki
# Processing Record 27 of Set 8 | tawang
# Processing Record 28 of Set 8 | talcahuano
# Processing Record 29 of Set 8 | jiuquan
# Processing Record 30 of Set 8 | sereflikochisar
# Processing Record 31 of Set 8 | kloulklubed
# Processing Record 32 of Set 8 | port blair
# Processing Record 33 of Set 8 | leh
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | dergachi
# Processing Record 36 of Set 8 | san quintin
# Processing Record 37 of Set 8 | itoman
# Processing Record 38 of Set 8 | calbuco
# Processing Record 39 of Set 8 | skjervoy
# Processing Record 40 of Set 8 | chabahar
# Processing Record 41 of Set 8 | linfen
# Processing Record 42 of Set 8 | kharabali
# Processing Record 43 of Set 8 | kijang
# Processing Record 44 of Set 8 | dawson creek
# Processing Record 45 of Set 8 | blacksburg
# Processing Record 46 of Set 8 | mahebourg
# Processing Record 47 of Set 8 | okhotsk
# Processing Record 48 of Set 8 | mucurapo
# Processing Record 49 of Set 8 | wasco
# Processing Record 50 of Set 8 | san rafael
# Processing Record 1 of Set 9 | denia
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | sangar
# Processing Record 4 of Set 9 | campos novos
# Processing Record 5 of Set 9 | cheremukhovo
# Processing Record 6 of Set 9 | sovetskiy
# Processing Record 7 of Set 9 | dong hoi
# Processing Record 8 of Set 9 | kiunga
# Processing Record 9 of Set 9 | diffa
# Processing Record 10 of Set 9 | hasaki
# Processing Record 11 of Set 9 | morena
# Processing Record 12 of Set 9 | lakes entrance
# Processing Record 13 of Set 9 | mitsamiouli
# Processing Record 14 of Set 9 | ust-tarka
# Processing Record 15 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 9 | acarau
# Processing Record 17 of Set 9 | kikwit
# Processing Record 18 of Set 9 | vanimo
# Processing Record 19 of Set 9 | marawi
# Processing Record 20 of Set 9 | ichinoseki
# Processing Record 21 of Set 9 | gravina in puglia
# Processing Record 22 of Set 9 | barras
# Processing Record 23 of Set 9 | almaty
# Processing Record 24 of Set 9 | nishihara
# Processing Record 25 of Set 9 | yaypan
# Processing Record 26 of Set 9 | anadyr
# Processing Record 27 of Set 9 | terrace
# Processing Record 28 of Set 9 | san fernando
# Processing Record 29 of Set 9 | sao filipe
# Processing Record 30 of Set 9 | polovinnoye
# Processing Record 31 of Set 9 | bollnas
# Processing Record 32 of Set 9 | buala
# Processing Record 33 of Set 9 | strezhevoy
# Processing Record 34 of Set 9 | puerto quijarro
# Processing Record 35 of Set 9 | chokurdakh
# Processing Record 36 of Set 9 | constitucion
# Processing Record 37 of Set 9 | finschhafen
# Processing Record 38 of Set 9 | mayumba
# Processing Record 39 of Set 9 | arkhangelsk
# Processing Record 40 of Set 9 | djougou
# Processing Record 41 of Set 9 | khor
# Processing Record 42 of Set 9 | sur
# Processing Record 43 of Set 9 | hami
# Processing Record 44 of Set 9 | kolokani
# Processing Record 45 of Set 9 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 46 of Set 9 | rokytne
# Processing Record 47 of Set 9 | kavieng
# Processing Record 48 of Set 9 | calama
# Processing Record 49 of Set 9 | kamaishi
# Processing Record 50 of Set 9 | mantua
# Processing Record 1 of Set 10 | saint-joseph
# Processing Record 2 of Set 10 | ostrovnoy
# Processing Record 3 of Set 10 | xining
# Processing Record 4 of Set 10 | oranjemund
# Processing Record 5 of Set 10 | rocha
# Processing Record 6 of Set 10 | biak
# Processing Record 7 of Set 10 | porto empedocle
# Processing Record 8 of Set 10 | maniitsoq
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | bargi
# Processing Record 11 of Set 10 | vieques
# Processing Record 12 of Set 10 | zherdevka
# Processing Record 13 of Set 10 | bay roberts
# Processing Record 14 of Set 10 | bud
# Processing Record 15 of Set 10 | oberwart
# Processing Record 16 of Set 10 | krasnoselkup
# Processing Record 17 of Set 10 | chibombo
# Processing Record 18 of Set 10 | villa constitucion
# Processing Record 19 of Set 10 | coquimbo
# Processing Record 20 of Set 10 | lakefield
# Processing Record 21 of Set 10 | tromso
# Processing Record 22 of Set 10 | kampot
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | tikapur
# Processing Record 25 of Set 10 | usingen
# Processing Record 26 of Set 10 | san patricio
# Processing Record 27 of Set 10 | jalu
# Processing Record 28 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 29 of Set 10 | leua
# Processing Record 30 of Set 10 | faya
# Processing Record 31 of Set 10 | tautira
# Processing Record 32 of Set 10 | itarema
# Processing Record 33 of Set 10 | solnechnogorsk
# Processing Record 34 of Set 10 | syracuse
# Processing Record 35 of Set 10 | tsalenjikha
# Processing Record 36 of Set 10 | ciudad bolivar
# Processing Record 37 of Set 10 | biswan
# Processing Record 38 of Set 10 | varnavino
# Processing Record 39 of Set 10 | marand
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | mongoumba
# Processing Record 44 of Set 10 | bonavista
# Processing Record 45 of Set 10 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | grand gaube
# Processing Record 47 of Set 10 | malartic
# Processing Record 48 of Set 10 | chara
# Processing Record 49 of Set 10 | vostok
# Processing Record 50 of Set 10 | novobirilyussy
# Processing Record 1 of Set 11 | yumen
# Processing Record 2 of Set 11 | kawalu
# Processing Record 3 of Set 11 | estelle
# Processing Record 4 of Set 11 | udachnyy
# Processing Record 5 of Set 11 | puerto palomas
# Processing Record 6 of Set 11 | addis zemen
# City not found. Skipping...
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | andenes
# Processing Record 9 of Set 11 | ust-maya
# Processing Record 10 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 11 | brae
# Processing Record 12 of Set 11 | havre
# Processing Record 13 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 14 of Set 11 | jakar
# Processing Record 15 of Set 11 | marystown
# Processing Record 16 of Set 11 | huarmey
# Processing Record 17 of Set 11 | seoul
# Processing Record 18 of Set 11 | mezhdurechenskiy
# Processing Record 19 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 11 | almeirim
# Processing Record 21 of Set 11 | haapiti
# Processing Record 22 of Set 11 | kavaratti
# Processing Record 23 of Set 11 | porbandar
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | diamantino
# Processing Record 26 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 11 | hounde
# Processing Record 28 of Set 11 | noumea
# Processing Record 29 of Set 11 | tual
# Processing Record 30 of Set 11 | partenit
# Processing Record 31 of Set 11 | ngaoundere
# Processing Record 32 of Set 11 | filadelfia
# Processing Record 33 of Set 11 | eyl
# Processing Record 34 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 11 | pauini
# Processing Record 36 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 11 | tornio
# Processing Record 38 of Set 11 | tamandare
# Processing Record 39 of Set 11 | birjand
# Processing Record 40 of Set 11 | indianola
# Processing Record 41 of Set 11 | constantine
# Processing Record 42 of Set 11 | hirado
# Processing Record 43 of Set 11 | shingu
# Processing Record 44 of Set 11 | klyuchi
# Processing Record 45 of Set 11 | kalemie
# Processing Record 46 of Set 11 | kainantu
# Processing Record 47 of Set 11 | araguari
# Processing Record 48 of Set 11 | ulladulla
# Processing Record 49 of Set 11 | chernyshevskiy
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | half moon bay
# Processing Record 3 of Set 12 | alekseyevsk
# Processing Record 4 of Set 12 | khani
# Processing Record 5 of Set 12 | sinnamary
# Processing Record 6 of Set 12 | san javier
# Processing Record 7 of Set 12 | chumikan
# Processing Record 8 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 9 of Set 12 | huilong
# Processing Record 10 of Set 12 | kerema
# Processing Record 11 of Set 12 | chistogorskiy
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | fairbanks
# Processing Record 14 of Set 12 | kabo
# Processing Record 15 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 12 | sfantu gheorghe
# Processing Record 17 of Set 12 | vozhd proletariata
# City not found. Skipping...
# Processing Record 18 of Set 12 | freeport
# Processing Record 19 of Set 12 | macusani
# Processing Record 20 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 21 of Set 12 | chute-aux-outardes
# Processing Record 22 of Set 12 | ardakan
# Processing Record 23 of Set 12 | stornoway
# Processing Record 24 of Set 12 | notse
# Processing Record 25 of Set 12 | whitefish
# Processing Record 26 of Set 12 | verkhnevilyuysk
# Processing Record 27 of Set 12 | viedma
# Processing Record 28 of Set 12 | phuket
# Processing Record 29 of Set 12 | lubango
# Processing Record 30 of Set 12 | opuwo
# Processing Record 31 of Set 12 | big spring
# Processing Record 32 of Set 12 | voh
# Processing Record 33 of Set 12 | corinto
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | emborion
# Processing Record 36 of Set 12 | nakamura
# Processing Record 37 of Set 12 | kagadi
# Processing Record 38 of Set 12 | sandnessjoen
# Processing Record 39 of Set 12 | taoudenni
# Processing Record 40 of Set 12 | solnechnyy
# Processing Record 41 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 12 | lianzhou
# Processing Record 43 of Set 12 | santa vitoria do palmar
# Processing Record 44 of Set 12 | shimoda
# Processing Record 45 of Set 12 | morros
# Processing Record 46 of Set 12 | abu samrah
# Processing Record 47 of Set 12 | ancud
# Processing Record 48 of Set 12 | inta
# Processing Record 49 of Set 12 | zhongshu
# Processing Record 50 of Set 12 | obera
# Processing Record 1 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 13 | mitha tiwana
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | panjakent
# Processing Record 5 of Set 13 | marinette
# Processing Record 6 of Set 13 | qaqortoq
# Processing Record 7 of Set 13 | torata
# Processing Record 8 of Set 13 | ibra
# Processing Record 9 of Set 13 | richards bay
# Processing Record 10 of Set 13 | inhambane
# Processing Record 11 of Set 13 | nerchinskiy zavod
# Processing Record 12 of Set 13 | meulaboh
# Processing Record 13 of Set 13 | pundaguitan
# Processing Record 14 of Set 13 | comodoro rivadavia
# Processing Record 15 of Set 13 | maputo
# Processing Record 16 of Set 13 | sorland
# Processing Record 17 of Set 13 | banda aceh
# Processing Record 18 of Set 13 | majene
# Processing Record 19 of Set 13 | omsukchan
# Processing Record 20 of Set 13 | mayo
# Processing Record 21 of Set 13 | guaratinga
# Processing Record 22 of Set 13 | alassio
# Processing Record 23 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 13 | morogoro
# Processing Record 25 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 13 | cockburn town
# Processing Record 27 of Set 13 | mathathane
# Processing Record 28 of Set 13 | bell ville
# Processing Record 29 of Set 13 | starobesheve
# Processing Record 30 of Set 13 | johi
# Processing Record 31 of Set 13 | poronaysk
# Processing Record 32 of Set 13 | mahajanga
# Processing Record 33 of Set 13 | lingyuan
# Processing Record 34 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 13 | saint-georges
# Processing Record 36 of Set 13 | mount isa
# Processing Record 37 of Set 13 | imeni zhelyabova
# Processing Record 38 of Set 13 | skibbereen
# Processing Record 39 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 40 of Set 13 | emerald
# Processing Record 41 of Set 13 | grand-santi
# Processing Record 42 of Set 13 | yankton
# Processing Record 43 of Set 13 | tobane
# Processing Record 44 of Set 13 | pervomayskiy
# Processing Record 45 of Set 13 | aracati
# Processing Record 46 of Set 13 | matara
# Processing Record 47 of Set 13 | fartanesti
# City not found. Skipping...
# Processing Record 48 of Set 13 | maceio
# Processing Record 49 of Set 13 | kushima
# Processing Record 50 of Set 13 | bayburt
# Processing Record 1 of Set 14 | tigil
# Processing Record 2 of Set 14 | wanlaweyn
# Processing Record 3 of Set 14 | oyama
# Processing Record 4 of Set 14 | ploemeur
# Processing Record 5 of Set 14 | arya
# Processing Record 6 of Set 14 | vangaindrano
# Processing Record 7 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 14 | road town
# Processing Record 9 of Set 14 | zyryanka
# Processing Record 10 of Set 14 | yebaishou
# Processing Record 11 of Set 14 | barcelos
# Processing Record 12 of Set 14 | correntina
# Processing Record 13 of Set 14 | tiznit
# Processing Record 14 of Set 14 | qinzhou
# Processing Record 15 of Set 14 | carutapera
# Processing Record 16 of Set 14 | rizhao
# Processing Record 17 of Set 14 | taburao
# City not found. Skipping...
# Processing Record 18 of Set 14 | semey
# Processing Record 19 of Set 14 | sokoni
# Processing Record 20 of Set 14 | savannah bight
# Processing Record 21 of Set 14 | yatou
# Processing Record 22 of Set 14 | bend
# Processing Record 23 of Set 14 | channel-port aux basques
# Processing Record 24 of Set 14 | coari
# Processing Record 25 of Set 14 | olden
# Processing Record 26 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 14 | wattegama
# Processing Record 28 of Set 14 | batticaloa
# Processing Record 29 of Set 14 | cumberland
# Processing Record 30 of Set 14 | muros
# Processing Record 31 of Set 14 | takoradi
# Processing Record 32 of Set 14 | brigham city
# Processing Record 33 of Set 14 | razdolnoye
# Processing Record 34 of Set 14 | moyale
# Processing Record 35 of Set 14 | prado
# Processing Record 36 of Set 14 | champerico
# Processing Record 37 of Set 14 | pedra azul
# Processing Record 38 of Set 14 | ust-kuyga
# Processing Record 39 of Set 14 | lujan
# Processing Record 40 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 14 | tomatlan
# Processing Record 42 of Set 14 | roros
# Processing Record 43 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 14 | onega
# Processing Record 45 of Set 14 | mukdahan
# Processing Record 46 of Set 14 | dukat
# Processing Record 47 of Set 14 | erzin
# Processing Record 48 of Set 14 | palmital
# Processing Record 49 of Set 14 | provost
# Processing Record 50 of Set 14 | north bend
# Processing Record 1 of Set 15 | chesma
# Processing Record 2 of Set 15 | cambyreta
# City not found. Skipping...
# Processing Record 3 of Set 15 | merke
# Processing Record 4 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 15 | belogorsk
# Processing Record 6 of Set 15 | nuevo progreso
# Processing Record 7 of Set 15 | nola
# Processing Record 8 of Set 15 | angoche
# Processing Record 9 of Set 15 | mikuni
# Processing Record 10 of Set 15 | albion
# Processing Record 11 of Set 15 | kotelnich
# Processing Record 12 of Set 15 | menongue
# Processing Record 13 of Set 15 | bendigo
# Processing Record 14 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 15 | maroantsetra
# Processing Record 16 of Set 15 | thinadhoo
# Processing Record 17 of Set 15 | raver
# Processing Record 18 of Set 15 | gari
# Processing Record 19 of Set 15 | poya
# Processing Record 20 of Set 15 | kangaba
# Processing Record 21 of Set 15 | guerrero negro
# Processing Record 22 of Set 15 | luba
# Processing Record 23 of Set 15 | xai-xai
# Processing Record 24 of Set 15 | sug-aksy
# City not found. Skipping...
# Processing Record 25 of Set 15 | kawakawa
# Processing Record 26 of Set 15 | les cayes
# Processing Record 27 of Set 15 | dovers
# Processing Record 28 of Set 15 | colombia
# Processing Record 29 of Set 15 | tiarei
# Processing Record 30 of Set 15 | sibu
# Processing Record 31 of Set 15 | tucurui
# Processing Record 32 of Set 15 | ziway
# Processing Record 33 of Set 15 | walvis bay
# Processing Record 34 of Set 15 | teya
# Processing Record 35 of Set 15 | denpasar
# Processing Record 36 of Set 15 | kinkala
# Processing Record 37 of Set 15 | tres lagoas
# Processing Record 38 of Set 15 | galatas
# Processing Record 39 of Set 15 | kutum
# Processing Record 40 of Set 15 | seybaplaya
# Processing Record 41 of Set 15 | roald
# Processing Record 42 of Set 15 | gobabis
# Processing Record 43 of Set 15 | kiboga
# Processing Record 44 of Set 15 | sabang
# Processing Record 45 of Set 15 | praia
# Processing Record 46 of Set 15 | martil
# Processing Record 47 of Set 15 | aksarka
# Processing Record 48 of Set 15 | bom jardim
# Processing Record 49 of Set 15 | darhan
# Processing Record 50 of Set 15 | kourou
# Processing Record 1 of Set 16 | bilara
# Processing Record 2 of Set 16 | kahuta
# Processing Record 3 of Set 16 | hualmay
# Processing Record 4 of Set 16 | candelaria
# Processing Record 5 of Set 16 | anzhero-sudzhensk
# Processing Record 6 of Set 16 | ponazyrevo
# Processing Record 7 of Set 16 | tukrah
# Processing Record 8 of Set 16 | gizo
# Processing Record 9 of Set 16 | labrea
# Processing Record 10 of Set 16 | santa ana
# Processing Record 11 of Set 16 | rawannawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Visby      SE  57.64   18.30     48.00        93          43
# 1           Mehran      IR  33.12   46.16     53.60        71           0
# 2        Jamestown      US  42.10  -79.24     60.80        48           1
# 3      Tuktoyaktuk      CA  69.45 -133.04      8.60        92          40
# 4       Georgetown      MY   5.41  100.34     78.80        83          40
# 5        Dharchula      IN  29.85   80.53     50.59        48           0
# 6     Puerto Ayora      EC  -0.74  -90.35     69.01        85           2
# 7          Qaanaaq      GL  77.48  -69.36     -8.05        70           0
# 8  Arraial Do Cabo      BR -22.97  -42.03     73.40        94          75
# 9          Rikitea      PF -23.12 -134.97     72.91        77         100
#
#    Wind Speed      Current Description
# 0        8.05         scattered clouds
# 1        4.70                clear sky
# 2        3.36                clear sky
# 3        2.24         scattered clouds
# 4        5.82         scattered clouds
# 5        2.93                clear sky
# 6        5.01                clear sky
# 7        9.44                clear sky
# 8        8.05  light intensity drizzle
# 9       15.57          overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
