# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8a2b5c868cecc3f05dd7641b2deb6f68

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
                
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | tottori
# Processing Record 5 of Set 1 | terney
# Processing Record 6 of Set 1 | torbat-e jam
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | lagoa
# Processing Record 10 of Set 1 | wembley
# Processing Record 11 of Set 1 | sabha
# Processing Record 12 of Set 1 | half moon bay
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | plast
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | ahmadnagar
# Processing Record 17 of Set 1 | itarema
# Processing Record 18 of Set 1 | champerico
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | khandbari
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | dudinka
# Processing Record 25 of Set 1 | yar-sale
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | cody
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | itoigawa
# Processing Record 30 of Set 1 | kasongo
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | victor harbor
# Processing Record 33 of Set 1 | the valley
# Processing Record 34 of Set 1 | sehithwa
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | almeirim
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | landeck
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | herne bay
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | dekar
# Processing Record 43 of Set 1 | port moresby
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 1 | karasburg
# Processing Record 1 of Set 2 | rybinsk
# Processing Record 2 of Set 2 | bengkulu
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | srednekolymsk
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | waipawa
# Processing Record 7 of Set 2 | port hedland
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | oistins
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | nhulunbuy
# Processing Record 16 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 17 of Set 2 | westport
# Processing Record 18 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | uray
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | mwinilunga
# Processing Record 25 of Set 2 | busselton
# Processing Record 26 of Set 2 | singaraja
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | fuyu
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | ivdel
# Processing Record 32 of Set 2 | kloulklubed
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | kathmandu
# Processing Record 35 of Set 2 | quatre cocos
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | ossora
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 2 | wabrzezno
# Processing Record 41 of Set 2 | chinhoyi
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | lander
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | inhambane
# Processing Record 49 of Set 2 | okhotsk
# Processing Record 50 of Set 2 | haines junction
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | calvinia
# Processing Record 4 of Set 3 | brockville
# Processing Record 5 of Set 3 | broome
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | darnah
# Processing Record 13 of Set 3 | alofi
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | cidreira
# Processing Record 16 of Set 3 | mildura
# Processing Record 17 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 3 | mahebourg
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | krotoszyn
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | clarence town
# Processing Record 24 of Set 3 | hastings
# Processing Record 25 of Set 3 | la palma
# Processing Record 26 of Set 3 | pionerskiy
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | namatanai
# Processing Record 29 of Set 3 | urumqi
# Processing Record 30 of Set 3 | yaan
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | dauriya
# Processing Record 34 of Set 3 | deputatskiy
# Processing Record 35 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 38 of Set 3 | podyuga
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | miri
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | saint-leu
# Processing Record 44 of Set 3 | orlik
# Processing Record 45 of Set 3 | saint george
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | aswan
# Processing Record 48 of Set 3 | alyangula
# Processing Record 49 of Set 3 | santa maria
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | timmins
# Processing Record 2 of Set 4 | limon
# Processing Record 3 of Set 4 | davila
# Processing Record 4 of Set 4 | olafsvik
# Processing Record 5 of Set 4 | costa rica
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | sur
# Processing Record 8 of Set 4 | los llanos de aridane
# Processing Record 9 of Set 4 | livermore
# Processing Record 10 of Set 4 | toktogul
# Processing Record 11 of Set 4 | moron
# Processing Record 12 of Set 4 | adrar
# Processing Record 13 of Set 4 | cooma
# Processing Record 14 of Set 4 | pontian kecil
# Processing Record 15 of Set 4 | otradnoye
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | rumphi
# Processing Record 18 of Set 4 | jishou
# Processing Record 19 of Set 4 | grand baie
# Processing Record 20 of Set 4 | presidencia roque saenz pena
# Processing Record 21 of Set 4 | tsabong
# Processing Record 22 of Set 4 | shelburne
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | college
# Processing Record 25 of Set 4 | sola
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | umm lajj
# Processing Record 28 of Set 4 | port alfred
# Processing Record 29 of Set 4 | nevelsk
# Processing Record 30 of Set 4 | sao miguel do araguaia
# Processing Record 31 of Set 4 | jibuti
# Processing Record 32 of Set 4 | grootfontein
# Processing Record 33 of Set 4 | asyut
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | kyaikkami
# Processing Record 36 of Set 4 | thinadhoo
# Processing Record 37 of Set 4 | emerald
# Processing Record 38 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | hare bay
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | port macquarie
# Processing Record 44 of Set 4 | grand gaube
# Processing Record 45 of Set 4 | omboue
# Processing Record 46 of Set 4 | mubende
# Processing Record 47 of Set 4 | salym
# Processing Record 48 of Set 4 | san lorenzo
# Processing Record 49 of Set 4 | ayr
# Processing Record 50 of Set 4 | chumikan
# Processing Record 1 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 2 of Set 5 | ambovombe
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | tual
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | tezu
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | taltal
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | saint-philippe
# Processing Record 13 of Set 5 | nioro
# Processing Record 14 of Set 5 | paamiut
# Processing Record 15 of Set 5 | kuryk
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | hounde
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | eureka
# Processing Record 21 of Set 5 | jiexiu
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | santa isabel do rio negro
# Processing Record 25 of Set 5 | pionki
# Processing Record 26 of Set 5 | hvide sande
# Processing Record 27 of Set 5 | fernley
# Processing Record 28 of Set 5 | verkhoyansk
# Processing Record 29 of Set 5 | barahan
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | nuuk
# Processing Record 32 of Set 5 | seara
# Processing Record 33 of Set 5 | puerto del rosario
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | onda
# Processing Record 39 of Set 5 | severo-kurilsk
# Processing Record 40 of Set 5 | asfi
# Processing Record 41 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 5 | la libertad
# Processing Record 43 of Set 5 | kasane
# Processing Record 44 of Set 5 | ouargaye
# Processing Record 45 of Set 5 | warrnambool
# Processing Record 46 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | akom
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | nakskov
# Processing Record 1 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 6 | hithadhoo
# Processing Record 3 of Set 6 | norman wells
# Processing Record 4 of Set 6 | mindelo
# Processing Record 5 of Set 6 | aquiraz
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | hamilton
# Processing Record 8 of Set 6 | karratha
# Processing Record 9 of Set 6 | datong
# Processing Record 10 of Set 6 | kuusamo
# Processing Record 11 of Set 6 | merauke
# Processing Record 12 of Set 6 | malindi
# Processing Record 13 of Set 6 | ranau
# Processing Record 14 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 6 | sorland
# Processing Record 16 of Set 6 | biltine
# Processing Record 17 of Set 6 | angoche
# Processing Record 18 of Set 6 | beira
# Processing Record 19 of Set 6 | barras
# Processing Record 20 of Set 6 | cururupu
# Processing Record 21 of Set 6 | fortuna
# Processing Record 22 of Set 6 | imbituba
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | hay river
# Processing Record 25 of Set 6 | lorengau
# Processing Record 26 of Set 6 | manadhoo
# Processing Record 27 of Set 6 | lamar
# Processing Record 28 of Set 6 | flin flon
# Processing Record 29 of Set 6 | caceres
# Processing Record 30 of Set 6 | zwedru
# Processing Record 31 of Set 6 | virginia beach
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | komatipoort
# Processing Record 34 of Set 6 | berlevag
# Processing Record 35 of Set 6 | salcedo
# Processing Record 36 of Set 6 | vestmannaeyjar
# Processing Record 37 of Set 6 | lakeway
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | karatau
# Processing Record 40 of Set 6 | reconquista
# Processing Record 41 of Set 6 | sabratah
# Processing Record 42 of Set 6 | vredendal
# Processing Record 43 of Set 6 | college station
# Processing Record 44 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 6 | humboldt
# Processing Record 46 of Set 6 | salaga
# Processing Record 47 of Set 6 | itapecerica da serra
# Processing Record 48 of Set 6 | general higinio morinigo
# Processing Record 49 of Set 6 | flinders
# Processing Record 50 of Set 6 | sisimiut
# Processing Record 1 of Set 7 | coahuayana
# Processing Record 2 of Set 7 | camabatela
# Processing Record 3 of Set 7 | chateauroux
# Processing Record 4 of Set 7 | biak
# Processing Record 5 of Set 7 | iqaluit
# Processing Record 6 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | zhigansk
# Processing Record 10 of Set 7 | nurpur
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | codrington
# Processing Record 14 of Set 7 | saint-joseph
# Processing Record 15 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 7 | auki
# Processing Record 17 of Set 7 | rundu
# Processing Record 18 of Set 7 | hobyo
# Processing Record 19 of Set 7 | shingu
# Processing Record 20 of Set 7 | ryazhsk
# Processing Record 21 of Set 7 | dhandhuka
# Processing Record 22 of Set 7 | aripuana
# Processing Record 23 of Set 7 | porto novo
# Processing Record 24 of Set 7 | nieuwpoort
# Processing Record 25 of Set 7 | roma
# Processing Record 26 of Set 7 | ludvika
# Processing Record 27 of Set 7 | marawi
# Processing Record 28 of Set 7 | ballina
# Processing Record 29 of Set 7 | kruisfontein
# Processing Record 30 of Set 7 | nokaneng
# Processing Record 31 of Set 7 | gidole
# Processing Record 32 of Set 7 | bonavista
# Processing Record 33 of Set 7 | hermanus
# Processing Record 34 of Set 7 | lambari
# Processing Record 35 of Set 7 | luanda
# Processing Record 36 of Set 7 | koulikoro
# Processing Record 37 of Set 7 | bimbo
# Processing Record 38 of Set 7 | warrington
# Processing Record 39 of Set 7 | babati
# Processing Record 40 of Set 7 | belmopan
# Processing Record 41 of Set 7 | amatlan
# City not found. Skipping...
# Processing Record 42 of Set 7 | ponta do sol
# Processing Record 43 of Set 7 | sainte-anne-des-monts
# Processing Record 44 of Set 7 | balsas
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | antofagasta
# Processing Record 47 of Set 7 | lebu
# Processing Record 48 of Set 7 | sao felix do xingu
# Processing Record 49 of Set 7 | bubaque
# Processing Record 50 of Set 7 | tilichiki
# Processing Record 1 of Set 8 | vaitape
# Processing Record 2 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 8 | kaduqli
# Processing Record 4 of Set 8 | zaysan
# Processing Record 5 of Set 8 | jiaojiang
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | rock springs
# Processing Record 8 of Set 8 | kalmunai
# Processing Record 9 of Set 8 | mahajanga
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | asau
# Processing Record 12 of Set 8 | upernavik
# Processing Record 13 of Set 8 | tubarao
# Processing Record 14 of Set 8 | clyde river
# Processing Record 15 of Set 8 | sri aman
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | tessalit
# Processing Record 18 of Set 8 | kathu
# Processing Record 19 of Set 8 | nemuro
# Processing Record 20 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 21 of Set 8 | ahipara
# Processing Record 22 of Set 8 | weiser
# Processing Record 23 of Set 8 | gat
# Processing Record 24 of Set 8 | indiaroba
# Processing Record 25 of Set 8 | rosehearty
# Processing Record 26 of Set 8 | gambita
# City not found. Skipping...
# Processing Record 27 of Set 8 | castelbuono
# Processing Record 28 of Set 8 | moussoro
# Processing Record 29 of Set 8 | kristiansund
# Processing Record 30 of Set 8 | berberati
# Processing Record 31 of Set 8 | havelock
# Processing Record 32 of Set 8 | majene
# Processing Record 33 of Set 8 | bambanglipuro
# Processing Record 34 of Set 8 | pasni
# Processing Record 35 of Set 8 | moindou
# Processing Record 36 of Set 8 | mwene-ditu
# Processing Record 37 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 8 | lazaro cardenas
# Processing Record 39 of Set 8 | jaciara
# Processing Record 40 of Set 8 | lavrentiya
# Processing Record 41 of Set 8 | paragominas
# Processing Record 42 of Set 8 | airai
# Processing Record 43 of Set 8 | mount isa
# Processing Record 44 of Set 8 | saint-pierre
# Processing Record 45 of Set 8 | maiduguri
# Processing Record 46 of Set 8 | makakilo city
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | egvekinot
# Processing Record 49 of Set 8 | chapais
# Processing Record 50 of Set 8 | tuatapere
# Processing Record 1 of Set 9 | sao jose da coroa grande
# Processing Record 2 of Set 9 | piranshahr
# Processing Record 3 of Set 9 | bose
# Processing Record 4 of Set 9 | baker city
# Processing Record 5 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 9 | taksimo
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | aykhal
# Processing Record 9 of Set 9 | narsaq
# Processing Record 10 of Set 9 | mackenzie
# Processing Record 11 of Set 9 | fort nelson
# Processing Record 12 of Set 9 | zheleznodorozhnyy
# Processing Record 13 of Set 9 | shache
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | labytnangi
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | chilca
# Processing Record 18 of Set 9 | seka
# Processing Record 19 of Set 9 | zhanaozen
# Processing Record 20 of Set 9 | bahia blanca
# Processing Record 21 of Set 9 | sept-iles
# Processing Record 22 of Set 9 | severnyy
# Processing Record 23 of Set 9 | sandwick
# Processing Record 24 of Set 9 | caucaia
# Processing Record 25 of Set 9 | kattivakkam
# Processing Record 26 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 9 | hasaki
# Processing Record 28 of Set 9 | batticaloa
# Processing Record 29 of Set 9 | tianpeng
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | chornobayivka
# Processing Record 33 of Set 9 | minden
# Processing Record 34 of Set 9 | mattru
# Processing Record 35 of Set 9 | mozarlandia
# Processing Record 36 of Set 9 | uhlove
# Processing Record 37 of Set 9 | luwuk
# Processing Record 38 of Set 9 | osypenko
# Processing Record 39 of Set 9 | cedar rapids
# Processing Record 40 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 41 of Set 9 | dunga bunga
# Processing Record 42 of Set 9 | moose factory
# Processing Record 43 of Set 9 | avera
# Processing Record 44 of Set 9 | olovyannaya
# Processing Record 45 of Set 9 | neubrandenburg
# Processing Record 46 of Set 9 | shaoyang
# Processing Record 47 of Set 9 | chengdu
# Processing Record 48 of Set 9 | samarai
# Processing Record 49 of Set 9 | iberia
# Processing Record 50 of Set 9 | soyaux
# Processing Record 1 of Set 10 | senanga
# Processing Record 2 of Set 10 | oyama
# Processing Record 3 of Set 10 | nagato
# Processing Record 4 of Set 10 | cochrane
# Processing Record 5 of Set 10 | sinnamary
# Processing Record 6 of Set 10 | barra do garcas
# Processing Record 7 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 8 of Set 10 | kimbe
# Processing Record 9 of Set 10 | utiel
# Processing Record 10 of Set 10 | rabo de peixe
# Processing Record 11 of Set 10 | mount pleasant
# Processing Record 12 of Set 10 | padang
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | nador
# Processing Record 15 of Set 10 | buala
# Processing Record 16 of Set 10 | oyek
# Processing Record 17 of Set 10 | maneadero
# Processing Record 18 of Set 10 | riyadh
# Processing Record 19 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 20 of Set 10 | pozega
# Processing Record 21 of Set 10 | hudson bay
# Processing Record 22 of Set 10 | melfi
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | maarianhamina
# Processing Record 25 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 10 | gondanglegi
# Processing Record 27 of Set 10 | porbandar
# Processing Record 28 of Set 10 | ayios kirikos
# City not found. Skipping...
# Processing Record 29 of Set 10 | guarapari
# Processing Record 30 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 10 | waw
# Processing Record 32 of Set 10 | corinto
# Processing Record 33 of Set 10 | san jose
# Processing Record 34 of Set 10 | christchurch
# Processing Record 35 of Set 10 | jinxiang
# Processing Record 36 of Set 10 | ankang
# Processing Record 37 of Set 10 | hrymayliv
# Processing Record 38 of Set 10 | hambantota
# Processing Record 39 of Set 10 | lithakia
# Processing Record 40 of Set 10 | nuevo progreso
# Processing Record 41 of Set 10 | diego de almagro
# Processing Record 42 of Set 10 | koungou
# Processing Record 43 of Set 10 | bafia
# Processing Record 44 of Set 10 | edson
# Processing Record 45 of Set 10 | trenggalek
# Processing Record 46 of Set 10 | lima
# Processing Record 47 of Set 10 | constitucion
# Processing Record 48 of Set 10 | kupang
# Processing Record 49 of Set 10 | chulman
# Processing Record 50 of Set 10 | lubango
# Processing Record 1 of Set 11 | krasnogvardeyskiy
# Processing Record 2 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 3 of Set 11 | wenling
# Processing Record 4 of Set 11 | westlock
# Processing Record 5 of Set 11 | kaukauna
# Processing Record 6 of Set 11 | buta
# Processing Record 7 of Set 11 | jumla
# Processing Record 8 of Set 11 | gouyave
# Processing Record 9 of Set 11 | werda
# Processing Record 10 of Set 11 | tomatlan
# Processing Record 11 of Set 11 | saryg-sep
# Processing Record 12 of Set 11 | ayios petros
# City not found. Skipping...
# Processing Record 13 of Set 11 | minab
# Processing Record 14 of Set 11 | isla mujeres
# Processing Record 15 of Set 11 | hirara
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | maracacume
# Processing Record 18 of Set 11 | krasnaya gora
# Processing Record 19 of Set 11 | kashan
# Processing Record 20 of Set 11 | bay roberts
# Processing Record 21 of Set 11 | nola
# Processing Record 22 of Set 11 | toamasina
# Processing Record 23 of Set 11 | inirida
# Processing Record 24 of Set 11 | stornoway
# Processing Record 25 of Set 11 | ferrol
# Processing Record 26 of Set 11 | grimstad
# Processing Record 27 of Set 11 | shiraz
# Processing Record 28 of Set 11 | fleetwood
# Processing Record 29 of Set 11 | tazovskiy
# Processing Record 30 of Set 11 | san cristobal
# Processing Record 31 of Set 11 | alta floresta
# Processing Record 32 of Set 11 | graaff-reinet
# Processing Record 33 of Set 11 | manuk mangkaw
# Processing Record 34 of Set 11 | goderich
# Processing Record 35 of Set 11 | kieta
# Processing Record 36 of Set 11 | begles
# Processing Record 37 of Set 11 | saint-denis
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | chilmari
# Processing Record 40 of Set 11 | yumen
# Processing Record 41 of Set 11 | hakkari
# Processing Record 42 of Set 11 | luderitz
# Processing Record 43 of Set 11 | maraa
# Processing Record 44 of Set 11 | pochutla
# Processing Record 45 of Set 11 | menongue
# Processing Record 46 of Set 11 | tura
# Processing Record 47 of Set 11 | neka
# Processing Record 48 of Set 11 | ajaccio
# Processing Record 49 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 11 | monterey
# Processing Record 1 of Set 12 | kautokeino
# Processing Record 2 of Set 12 | la spezia
# Processing Record 3 of Set 12 | ukiah
# Processing Record 4 of Set 12 | diamantino
# Processing Record 5 of Set 12 | urusha
# Processing Record 6 of Set 12 | albert town
# Processing Record 7 of Set 12 | iglesias
# Processing Record 8 of Set 12 | mehamn
# Processing Record 9 of Set 12 | lunenburg
# Processing Record 10 of Set 12 | lokoja
# Processing Record 11 of Set 12 | lumphat
# Processing Record 12 of Set 12 | dawei
# Processing Record 13 of Set 12 | san matias
# Processing Record 14 of Set 12 | khorramshahr
# Processing Record 15 of Set 12 | bazarnyye mataki
# Processing Record 16 of Set 12 | amreli
# Processing Record 17 of Set 12 | luza
# Processing Record 18 of Set 12 | trairi
# Processing Record 19 of Set 12 | samarkand
# Processing Record 20 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 12 | pacific grove
# Processing Record 22 of Set 12 | punta alta
# Processing Record 23 of Set 12 | kapuskasing
# Processing Record 24 of Set 12 | port-gentil
# Processing Record 25 of Set 12 | san pedro
# Processing Record 26 of Set 12 | soyo
# Processing Record 27 of Set 12 | matagami
# Processing Record 28 of Set 12 | svobodnyy
# Processing Record 29 of Set 12 | matay
# Processing Record 30 of Set 12 | san rafael del sur
# Processing Record 31 of Set 12 | igarka
# Processing Record 32 of Set 12 | vanimo
# Processing Record 33 of Set 12 | statesville
# Processing Record 34 of Set 12 | yershov
# Processing Record 35 of Set 12 | san patricio
# Processing Record 36 of Set 12 | acari
# Processing Record 37 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 12 | vilyuysk
# Processing Record 39 of Set 12 | agsu
# City not found. Skipping...
# Processing Record 40 of Set 12 | lethem
# Processing Record 41 of Set 12 | tarboro
# Processing Record 42 of Set 12 | lichinga
# Processing Record 43 of Set 12 | farafenni
# Processing Record 44 of Set 12 | saint anthony
# Processing Record 45 of Set 12 | rosita
# Processing Record 46 of Set 12 | paso del macho
# Processing Record 47 of Set 12 | montepuez
# Processing Record 48 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 12 | salinopolis
# Processing Record 50 of Set 12 | mount vernon
# Processing Record 1 of Set 13 | brejinho
# Processing Record 2 of Set 13 | wexford
# Processing Record 3 of Set 13 | eirunepe
# Processing Record 4 of Set 13 | ipixuna
# Processing Record 5 of Set 13 | raga
# Processing Record 6 of Set 13 | coihaique
# Processing Record 7 of Set 13 | roblin
# Processing Record 8 of Set 13 | kahului
# Processing Record 9 of Set 13 | madras
# Processing Record 10 of Set 13 | taoudenni
# Processing Record 11 of Set 13 | englehart
# Processing Record 12 of Set 13 | lahat
# Processing Record 13 of Set 13 | sergeyevka
# Processing Record 14 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 13 | akdepe
# Processing Record 16 of Set 13 | dinga
# Processing Record 17 of Set 13 | porto santo
# Processing Record 18 of Set 13 | port keats
# Processing Record 19 of Set 13 | muroto
# Processing Record 20 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 13 | bellavista
# Processing Record 22 of Set 13 | alexandria
# Processing Record 23 of Set 13 | coquimbo
# Processing Record 24 of Set 13 | magistralnyy
# Processing Record 25 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 13 | pisco
# Processing Record 27 of Set 13 | awbari
# Processing Record 28 of Set 13 | watertown
# Processing Record 29 of Set 13 | umkomaas
# Processing Record 30 of Set 13 | marsh harbour
# Processing Record 31 of Set 13 | la rochelle
# Processing Record 32 of Set 13 | miracema do tocantins
# Processing Record 33 of Set 13 | nantucket
# Processing Record 34 of Set 13 | san ignacio
# Processing Record 35 of Set 13 | bereda
# Processing Record 36 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 13 | vao
# Processing Record 38 of Set 13 | dingle
# Processing Record 39 of Set 13 | dunedin
# Processing Record 40 of Set 13 | san julian
# Processing Record 41 of Set 13 | hearst
# Processing Record 42 of Set 13 | farmington
# Processing Record 43 of Set 13 | ortigueira
# Processing Record 44 of Set 13 | vzmorye
# Processing Record 45 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 13 | okato
# Processing Record 47 of Set 13 | siocon
# Processing Record 48 of Set 13 | visnes
# Processing Record 49 of Set 13 | mantua
# Processing Record 50 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 14 | lafiagi
# Processing Record 2 of Set 14 | newport
# Processing Record 3 of Set 14 | itoman
# Processing Record 4 of Set 14 | craig
# Processing Record 5 of Set 14 | sahuaripa
# Processing Record 6 of Set 14 | praia
# Processing Record 7 of Set 14 | port blair
# Processing Record 8 of Set 14 | abalak
# Processing Record 9 of Set 14 | preston
# Processing Record 10 of Set 14 | la suiza
# Processing Record 11 of Set 14 | nigde
# Processing Record 12 of Set 14 | aklavik
# Processing Record 13 of Set 14 | ukwa
# Processing Record 14 of Set 14 | palestine
# Processing Record 15 of Set 14 | iwaki
# Processing Record 16 of Set 14 | amapa
# Processing Record 17 of Set 14 | mareeba
# Processing Record 18 of Set 14 | morehead
# Processing Record 19 of Set 14 | kannauj
# Processing Record 20 of Set 14 | iranshahr
# Processing Record 21 of Set 14 | villa carlos paz
# Processing Record 22 of Set 14 | cairns
# Processing Record 23 of Set 14 | ouesso
# Processing Record 24 of Set 14 | shaoguan
# Processing Record 25 of Set 14 | inuvik
# Processing Record 26 of Set 14 | lukang
# Processing Record 27 of Set 14 | pangody
# Processing Record 28 of Set 14 | namie
# Processing Record 29 of Set 14 | talara
# Processing Record 30 of Set 14 | mogadishu
# Processing Record 31 of Set 14 | anadyr
# Processing Record 32 of Set 14 | gisborne
# Processing Record 33 of Set 14 | totskoye
# Processing Record 34 of Set 14 | takoradi
# Processing Record 35 of Set 14 | bilibino
# Processing Record 36 of Set 14 | komsomolskiy
# Processing Record 37 of Set 14 | katherine
# Processing Record 38 of Set 14 | kiama
# Processing Record 39 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 14 | passau
# Processing Record 41 of Set 14 | maragogi
# Processing Record 42 of Set 14 | filingue
# Processing Record 43 of Set 14 | ahuimanu
# Processing Record 44 of Set 14 | rocha
# Processing Record 45 of Set 14 | chauk
# Processing Record 46 of Set 14 | olesnica
# Processing Record 47 of Set 14 | chulym
# Processing Record 48 of Set 14 | atar
# Processing Record 49 of Set 14 | oksfjord
# Processing Record 50 of Set 14 | margate
# Processing Record 1 of Set 15 | sioux city
# Processing Record 2 of Set 15 | miquelon
# Processing Record 3 of Set 15 | lufilufi
# Processing Record 4 of Set 15 | mayo
# Processing Record 5 of Set 15 | mandera
# Processing Record 6 of Set 15 | chippewa falls
# Processing Record 7 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 15 | andover
# Processing Record 9 of Set 15 | faanui
# Processing Record 10 of Set 15 | meulaboh
# Processing Record 11 of Set 15 | awjilah
# Processing Record 12 of Set 15 | belgrade
# Processing Record 13 of Set 15 | boundiali
# Processing Record 14 of Set 15 | yulara
# Processing Record 15 of Set 15 | romanovka
# Processing Record 16 of Set 15 | zeya
# Processing Record 17 of Set 15 | jalu
# Processing Record 18 of Set 15 | llanes
# Processing Record 19 of Set 15 | wladyslawowo
# Processing Record 20 of Set 15 | iskateley
# Processing Record 21 of Set 15 | manga
# Processing Record 22 of Set 15 | muisne
# Processing Record 23 of Set 15 | kodinsk
# Processing Record 24 of Set 15 | acapulco
# Processing Record 25 of Set 15 | rodrigues alves
# Processing Record 26 of Set 15 | ulundi
# Processing Record 27 of Set 15 | rio grande
# Processing Record 28 of Set 15 | agirish
# Processing Record 29 of Set 15 | mayumba
# Processing Record 30 of Set 15 | riohacha
# Processing Record 31 of Set 15 | melendugno
# Processing Record 32 of Set 15 | megion
# Processing Record 33 of Set 15 | north bend
# Processing Record 34 of Set 15 | houma
# Processing Record 35 of Set 15 | roald
# Processing Record 36 of Set 15 | borba
# Processing Record 37 of Set 15 | santa vitoria do palmar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.12 -134.97     72.63        80          34
# 1        Albany      US  42.60  -73.97     30.99        81           0
# 2         Bluff      NZ -46.60  168.33     59.58        57           0
# 3       Tottori      JP  35.50  134.23     53.60        58          40
# 4        Terney      RU  45.05  136.61     32.76        70           0
# 5  Torbat-E Jam      IR  35.24   60.62     53.49        35           0
# 6       Kavieng      PG  -2.57  150.80     86.13        68         100
# 7         Pevek      RU  69.70  170.31     -1.03        90          41
# 8         Lagoa      PT  39.05  -27.98     61.16        68          89
# 9       Wembley      AU -31.93  115.80     71.01        49           0
#
#    Wind Speed Current Description
# 0       17.81    scattered clouds
# 1        1.86          light rain
# 2        4.25           clear sky
# 3       11.41    scattered clouds
# 4       10.29           clear sky
# 5       10.31           clear sky
# 6        5.57          light rain
# 7        9.66    scattered clouds
# 8       17.43     overcast clouds
# 9       16.11           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
