# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather.values()
        city_description=[]
        for i in city_weather['weather']:
            city_description.append(i['description'])
        
              
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": str(city_description)[1:-1]})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | phan thiet
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | huichapan
# Processing Record 7 of Set 1 | puerto gaitan
# Processing Record 8 of Set 1 | cap malheureux
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | port hedland
# Processing Record 13 of Set 1 | joao pinheiro
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | samana
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | abu kamal
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | miyako
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | rawson
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | aklavik
# Processing Record 33 of Set 1 | rajapalaiyam
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | dunedin
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | mocuba
# Processing Record 39 of Set 1 | gushikawa
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | bridgton
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 1 | beloha
# Processing Record 47 of Set 1 | berdigestyakh
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | mangrol
# Processing Record 50 of Set 1 | luderitz
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | bridlington
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | takoradi
# Processing Record 6 of Set 2 | wufeng
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | vardo
# Processing Record 9 of Set 2 | pangody
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | hualmay
# Processing Record 12 of Set 2 | johnson city
# Processing Record 13 of Set 2 | filadelfia
# Processing Record 14 of Set 2 | yaguajay
# Processing Record 15 of Set 2 | san luis
# Processing Record 16 of Set 2 | saint-augustin
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | monzon
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | brae
# Processing Record 21 of Set 2 | oussouye
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | vila velha
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 2 | esperance
# Processing Record 28 of Set 2 | kuryk
# Processing Record 29 of Set 2 | opunake
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | saint-pierre
# Processing Record 32 of Set 2 | kyren
# Processing Record 33 of Set 2 | ixtapa
# Processing Record 34 of Set 2 | sambava
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | staryy nadym
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | ibra
# Processing Record 39 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | lexington
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | iquitos
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | mayumba
# Processing Record 46 of Set 2 | matara
# Processing Record 47 of Set 2 | roald
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | garhshankar
# Processing Record 50 of Set 2 | fort-shevchenko
# Processing Record 1 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | joshimath
# Processing Record 4 of Set 3 | peniche
# Processing Record 5 of Set 3 | port-gentil
# Processing Record 6 of Set 3 | ostrovnoy
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | muridke
# Processing Record 9 of Set 3 | bandarbeyla
# Processing Record 10 of Set 3 | kuytun
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | la sarre
# Processing Record 13 of Set 3 | boquira
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | vohibinany
# Processing Record 16 of Set 3 | charters towers
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | hervey bay
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | waslala
# Processing Record 24 of Set 3 | luena
# Processing Record 25 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 3 | saint-francois
# Processing Record 27 of Set 3 | malakal
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | shangqiu
# Processing Record 32 of Set 3 | batemans bay
# Processing Record 33 of Set 3 | volchikha
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | wuwei
# Processing Record 38 of Set 3 | yuanping
# Processing Record 39 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 40 of Set 3 | fuyang
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | kharp
# Processing Record 43 of Set 3 | tarauaca
# Processing Record 44 of Set 3 | belyy yar
# Processing Record 45 of Set 3 | butaritari
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | huarmey
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | mahajanga
# Processing Record 1 of Set 4 | marrakesh
# Processing Record 2 of Set 4 | iberia
# Processing Record 3 of Set 4 | dinguiraye
# Processing Record 4 of Set 4 | panacan
# Processing Record 5 of Set 4 | pacifica
# Processing Record 6 of Set 4 | vanavara
# Processing Record 7 of Set 4 | krasnovka
# Processing Record 8 of Set 4 | tual
# Processing Record 9 of Set 4 | jijiga
# Processing Record 10 of Set 4 | rio grande
# Processing Record 11 of Set 4 | marawi
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | katha
# City not found. Skipping...
# Processing Record 14 of Set 4 | vao
# Processing Record 15 of Set 4 | te anau
# Processing Record 16 of Set 4 | da nang
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | socoltenango
# Processing Record 21 of Set 4 | shache
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | bukama
# Processing Record 24 of Set 4 | quelimane
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | port alfred
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | jackson
# Processing Record 29 of Set 4 | long beach
# Processing Record 30 of Set 4 | cururupu
# Processing Record 31 of Set 4 | mata
# Processing Record 32 of Set 4 | eureka
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | khatanga
# Processing Record 35 of Set 4 | san juan bautista
# Processing Record 36 of Set 4 | makakilo city
# Processing Record 37 of Set 4 | hofn
# Processing Record 38 of Set 4 | alofi
# Processing Record 39 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | biak
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | ambon
# Processing Record 45 of Set 4 | le vauclin
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | kitui
# Processing Record 50 of Set 4 | evensk
# Processing Record 1 of Set 5 | las vegas
# Processing Record 2 of Set 5 | naryan-mar
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | cotonou
# Processing Record 5 of Set 5 | ketchikan
# Processing Record 6 of Set 5 | plouzane
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | linqiong
# Processing Record 9 of Set 5 | praia da vitoria
# Processing Record 10 of Set 5 | aljezur
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | san-pedro
# Processing Record 13 of Set 5 | zalantun
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | deputatskiy
# Processing Record 16 of Set 5 | port hardy
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | phonhong
# Processing Record 20 of Set 5 | lufilufi
# Processing Record 21 of Set 5 | zhanakorgan
# Processing Record 22 of Set 5 | baranain
# Processing Record 23 of Set 5 | haines junction
# Processing Record 24 of Set 5 | meadow lake
# Processing Record 25 of Set 5 | kolondieba
# Processing Record 26 of Set 5 | gat
# Processing Record 27 of Set 5 | tabou
# Processing Record 28 of Set 5 | pelym
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | finnentrop
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | katangli
# Processing Record 33 of Set 5 | rheinau
# Processing Record 34 of Set 5 | xuddur
# Processing Record 35 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 5 | tocatlan
# Processing Record 37 of Set 5 | east london
# Processing Record 38 of Set 5 | normal
# Processing Record 39 of Set 5 | chipata
# Processing Record 40 of Set 5 | okhotsk
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | acapulco
# Processing Record 43 of Set 5 | zyryanka
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 5 | temoac
# Processing Record 48 of Set 5 | lardos
# Processing Record 49 of Set 5 | navodari
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | naifaru
# Processing Record 2 of Set 6 | nong bua
# Processing Record 3 of Set 6 | iquique
# Processing Record 4 of Set 6 | epe
# Processing Record 5 of Set 6 | gubkinskiy
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | wau
# Processing Record 8 of Set 6 | omboue
# Processing Record 9 of Set 6 | batagay
# Processing Record 10 of Set 6 | ballina
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | amazar
# Processing Record 13 of Set 6 | tucuman
# Processing Record 14 of Set 6 | kamennogorsk
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | sovetskiy
# Processing Record 17 of Set 6 | graben-neudorf
# Processing Record 18 of Set 6 | crestview
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | hithadhoo
# Processing Record 21 of Set 6 | viedma
# Processing Record 22 of Set 6 | coracora
# Processing Record 23 of Set 6 | luziania
# Processing Record 24 of Set 6 | kayerkan
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | eltham
# Processing Record 27 of Set 6 | aksu
# Processing Record 28 of Set 6 | coquimbo
# Processing Record 29 of Set 6 | bonfim
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | monroe
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | coihaique
# Processing Record 34 of Set 6 | beisfjord
# Processing Record 35 of Set 6 | marystown
# Processing Record 36 of Set 6 | ibb
# Processing Record 37 of Set 6 | sibolga
# Processing Record 38 of Set 6 | seminole
# Processing Record 39 of Set 6 | kodiak
# Processing Record 40 of Set 6 | linxia
# Processing Record 41 of Set 6 | hamilton
# Processing Record 42 of Set 6 | atar
# Processing Record 43 of Set 6 | nara
# Processing Record 44 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 6 | pingzhuang
# Processing Record 46 of Set 6 | ust-maya
# Processing Record 47 of Set 6 | trindade
# Processing Record 48 of Set 6 | gorgan
# Processing Record 49 of Set 6 | mareeba
# Processing Record 50 of Set 6 | imbituba
# Processing Record 1 of Set 7 | san cristobal
# Processing Record 2 of Set 7 | kongolo
# Processing Record 3 of Set 7 | flin flon
# Processing Record 4 of Set 7 | katherine
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | sal rei
# Processing Record 7 of Set 7 | farafenni
# Processing Record 8 of Set 7 | pokrovsk
# Processing Record 9 of Set 7 | tessalit
# Processing Record 10 of Set 7 | gondar
# Processing Record 11 of Set 7 | kieta
# Processing Record 12 of Set 7 | havre
# Processing Record 13 of Set 7 | bathurst
# Processing Record 14 of Set 7 | gigmoto
# Processing Record 15 of Set 7 | bubaque
# Processing Record 16 of Set 7 | inuvik
# Processing Record 17 of Set 7 | coahuayana
# Processing Record 18 of Set 7 | marzuq
# Processing Record 19 of Set 7 | robe
# Processing Record 20 of Set 7 | lavrentiya
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | kruisfontein
# Processing Record 23 of Set 7 | kurilsk
# Processing Record 24 of Set 7 | klaksvik
# Processing Record 25 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 7 | gazojak
# Processing Record 28 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 7 | walvis bay
# Processing Record 30 of Set 7 | murray bridge
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | krasnorechenskiy
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | ambulu
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | kutum
# Processing Record 37 of Set 7 | waddan
# Processing Record 38 of Set 7 | santa rosa
# Processing Record 39 of Set 7 | mantua
# Processing Record 40 of Set 7 | maragogi
# Processing Record 41 of Set 7 | bogorodskoye
# Processing Record 42 of Set 7 | zorritos
# Processing Record 43 of Set 7 | north bend
# Processing Record 44 of Set 7 | douglas
# Processing Record 45 of Set 7 | makushino
# Processing Record 46 of Set 7 | tarakan
# Processing Record 47 of Set 7 | miri
# Processing Record 48 of Set 7 | ust-kuyga
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | khani
# Processing Record 1 of Set 8 | chekmagush
# Processing Record 2 of Set 8 | jatai
# Processing Record 3 of Set 8 | nouadhibou
# Processing Record 4 of Set 8 | sabzevar
# Processing Record 5 of Set 8 | panlaitan
# Processing Record 6 of Set 8 | shagonar
# Processing Record 7 of Set 8 | lorengau
# Processing Record 8 of Set 8 | saint george
# Processing Record 9 of Set 8 | thanh hoa
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | san patricio
# Processing Record 12 of Set 8 | werda
# Processing Record 13 of Set 8 | aripuana
# Processing Record 14 of Set 8 | canatlan
# Processing Record 15 of Set 8 | mount gambier
# Processing Record 16 of Set 8 | thinadhoo
# Processing Record 17 of Set 8 | bremerton
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | capaci
# Processing Record 20 of Set 8 | skjervoy
# Processing Record 21 of Set 8 | manado
# Processing Record 22 of Set 8 | tirumullaivasal
# Processing Record 23 of Set 8 | matagami
# Processing Record 24 of Set 8 | pisco
# Processing Record 25 of Set 8 | columbus
# Processing Record 26 of Set 8 | arman
# Processing Record 27 of Set 8 | pinawa
# Processing Record 28 of Set 8 | ibatiba
# Processing Record 29 of Set 8 | paita
# Processing Record 30 of Set 8 | muzhi
# Processing Record 31 of Set 8 | manlilinao
# Processing Record 32 of Set 8 | sapele
# Processing Record 33 of Set 8 | grindavik
# Processing Record 34 of Set 8 | knysna
# Processing Record 35 of Set 8 | orange
# Processing Record 36 of Set 8 | qandala
# Processing Record 37 of Set 8 | panama city
# Processing Record 38 of Set 8 | guerrero negro
# Processing Record 39 of Set 8 | kyritz
# Processing Record 40 of Set 8 | koulamoutou
# Processing Record 41 of Set 8 | launceston
# Processing Record 42 of Set 8 | chimore
# Processing Record 43 of Set 8 | mega
# Processing Record 44 of Set 8 | bairiki
# Processing Record 45 of Set 8 | andenes
# Processing Record 46 of Set 8 | ust-kalmanka
# Processing Record 47 of Set 8 | paramonga
# Processing Record 48 of Set 8 | kamenka
# Processing Record 49 of Set 8 | nuevo laredo
# Processing Record 50 of Set 8 | hassleholm
# Processing Record 1 of Set 9 | geraldton
# Processing Record 2 of Set 9 | inhambane
# Processing Record 3 of Set 9 | eskil
# Processing Record 4 of Set 9 | goderich
# Processing Record 5 of Set 9 | progreso
# Processing Record 6 of Set 9 | saskylakh
# Processing Record 7 of Set 9 | simbahan
# Processing Record 8 of Set 9 | savinskiy
# Processing Record 9 of Set 9 | vieques
# Processing Record 10 of Set 9 | pinhao
# Processing Record 11 of Set 9 | turayf
# Processing Record 12 of Set 9 | sokode
# Processing Record 13 of Set 9 | sawakin
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | morant bay
# Processing Record 16 of Set 9 | darnah
# Processing Record 17 of Set 9 | roma
# Processing Record 18 of Set 9 | luanda
# Processing Record 19 of Set 9 | haga
# Processing Record 20 of Set 9 | sakakah
# Processing Record 21 of Set 9 | midland
# Processing Record 22 of Set 9 | mehamn
# Processing Record 23 of Set 9 | erzin
# Processing Record 24 of Set 9 | bom jesus da lapa
# Processing Record 25 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 9 | hendaye
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | zhangye
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | noumea
# Processing Record 31 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 9 | salym
# Processing Record 33 of Set 9 | kenai
# Processing Record 34 of Set 9 | ranong
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | olafsvik
# Processing Record 37 of Set 9 | luau
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | agva
# City not found. Skipping...
# Processing Record 40 of Set 9 | namatanai
# Processing Record 41 of Set 9 | dano
# Processing Record 42 of Set 9 | yining
# Processing Record 43 of Set 9 | rapid valley
# Processing Record 44 of Set 9 | lumsden
# Processing Record 45 of Set 9 | touros
# Processing Record 46 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 9 | kyshtovka
# Processing Record 48 of Set 9 | jambi
# Processing Record 49 of Set 9 | camopi
# Processing Record 50 of Set 9 | sete
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | hongjiang
# Processing Record 3 of Set 10 | panarukan
# Processing Record 4 of Set 10 | dicabisagan
# Processing Record 5 of Set 10 | bodmin
# Processing Record 6 of Set 10 | burica
# City not found. Skipping...
# Processing Record 7 of Set 10 | damghan
# Processing Record 8 of Set 10 | nelson bay
# Processing Record 9 of Set 10 | xining
# Processing Record 10 of Set 10 | martapura
# Processing Record 11 of Set 10 | zeya
# Processing Record 12 of Set 10 | tambo
# Processing Record 13 of Set 10 | plettenberg bay
# Processing Record 14 of Set 10 | norman wells
# Processing Record 15 of Set 10 | vestmannaeyjar
# Processing Record 16 of Set 10 | palmeira
# Processing Record 17 of Set 10 | lahaina
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | zapolyarnyy
# Processing Record 20 of Set 10 | kitob
# Processing Record 21 of Set 10 | meulaboh
# Processing Record 22 of Set 10 | najran
# Processing Record 23 of Set 10 | taltal
# Processing Record 24 of Set 10 | gillette
# Processing Record 25 of Set 10 | antalaha
# Processing Record 26 of Set 10 | laguna
# Processing Record 27 of Set 10 | yashkino
# Processing Record 28 of Set 10 | vysotsk
# Processing Record 29 of Set 10 | ariquemes
# Processing Record 30 of Set 10 | poya
# Processing Record 31 of Set 10 | buala
# Processing Record 32 of Set 10 | nedjo
# Processing Record 33 of Set 10 | jalu
# Processing Record 34 of Set 10 | agirish
# Processing Record 35 of Set 10 | ciudad guayana
# Processing Record 36 of Set 10 | timra
# Processing Record 37 of Set 10 | alanya
# Processing Record 38 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 10 | mazatlan
# Processing Record 41 of Set 10 | iralaya
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | calvinia
# Processing Record 44 of Set 10 | honiara
# Processing Record 45 of Set 10 | manacapuru
# Processing Record 46 of Set 10 | dothan
# Processing Record 47 of Set 10 | vigeland
# Processing Record 48 of Set 10 | umm kaddadah
# Processing Record 49 of Set 10 | carutapera
# Processing Record 50 of Set 10 | binzhou
# Processing Record 1 of Set 11 | tecoanapa
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | aksarka
# Processing Record 4 of Set 11 | avera
# Processing Record 5 of Set 11 | kloulklubed
# Processing Record 6 of Set 11 | maltahohe
# Processing Record 7 of Set 11 | verkhoyansk
# Processing Record 8 of Set 11 | watsa
# Processing Record 9 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | senanga
# Processing Record 11 of Set 11 | camacha
# Processing Record 12 of Set 11 | mount isa
# Processing Record 13 of Set 11 | perelyub
# Processing Record 14 of Set 11 | shelburne
# Processing Record 15 of Set 11 | acajutla
# Processing Record 16 of Set 11 | syracuse
# Processing Record 17 of Set 11 | ploemeur
# Processing Record 18 of Set 11 | gogrial
# Processing Record 19 of Set 11 | barcelos
# Processing Record 20 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 11 | torbay
# Processing Record 22 of Set 11 | huambo
# Processing Record 23 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 11 | srednekolymsk
# Processing Record 25 of Set 11 | aitape
# Processing Record 26 of Set 11 | tostedt
# Processing Record 27 of Set 11 | gawler
# Processing Record 28 of Set 11 | sakhipur
# Processing Record 29 of Set 11 | juba
# Processing Record 30 of Set 11 | ambovombe
# Processing Record 31 of Set 11 | mackay
# Processing Record 32 of Set 11 | okha
# Processing Record 33 of Set 11 | onega
# Processing Record 34 of Set 11 | alekseyevsk
# Processing Record 35 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 36 of Set 11 | carballo
# Processing Record 37 of Set 11 | comodoro rivadavia
# Processing Record 38 of Set 11 | chute-aux-outardes
# Processing Record 39 of Set 11 | port moresby
# Processing Record 40 of Set 11 | nordenham
# Processing Record 41 of Set 11 | ahipara
# Processing Record 42 of Set 11 | leh
# Processing Record 43 of Set 11 | payette
# Processing Record 44 of Set 11 | vangaindrano
# Processing Record 45 of Set 11 | wageningen
# Processing Record 46 of Set 11 | tiarei
# Processing Record 47 of Set 11 | odweyne
# Processing Record 48 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 11 | cabedelo
# Processing Record 50 of Set 11 | westport
# Processing Record 1 of Set 12 | daru
# Processing Record 2 of Set 12 | sortavala
# Processing Record 3 of Set 12 | cayenne
# Processing Record 4 of Set 12 | prince rupert
# Processing Record 5 of Set 12 | bastrop
# Processing Record 6 of Set 12 | kashi
# Processing Record 7 of Set 12 | baiyin
# Processing Record 8 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 12 | las tunas
# Processing Record 10 of Set 12 | icod de los vinos
# Processing Record 11 of Set 12 | hirara
# Processing Record 12 of Set 12 | minsk mazowiecki
# Processing Record 13 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 12 | necocli
# Processing Record 15 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 12 | paamiut
# Processing Record 17 of Set 12 | chimbote
# Processing Record 18 of Set 12 | high rock
# Processing Record 19 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 12 | stornoway
# Processing Record 21 of Set 12 | beohari
# Processing Record 22 of Set 12 | canavieiras
# Processing Record 23 of Set 12 | ugoofaaru
# Processing Record 24 of Set 12 | tautira
# Processing Record 25 of Set 12 | panaba
# Processing Record 26 of Set 12 | lebedinyy
# Processing Record 27 of Set 12 | sola
# Processing Record 28 of Set 12 | sur
# Processing Record 29 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 30 of Set 12 | kawalu
# Processing Record 31 of Set 12 | sungai udang
# Processing Record 32 of Set 12 | chapada dos guimaraes
# Processing Record 33 of Set 12 | tres arroyos
# Processing Record 34 of Set 12 | durban
# Processing Record 35 of Set 12 | maldonado
# Processing Record 36 of Set 12 | bilibino
# Processing Record 37 of Set 12 | yuxia
# Processing Record 38 of Set 12 | caucaia
# Processing Record 39 of Set 12 | mayo
# Processing Record 40 of Set 12 | macaiba
# Processing Record 41 of Set 12 | faya
# Processing Record 42 of Set 12 | alice springs
# Processing Record 43 of Set 12 | san carlos park
# Processing Record 44 of Set 12 | calama
# Processing Record 45 of Set 12 | casino
# Processing Record 46 of Set 12 | boca do acre
# Processing Record 47 of Set 12 | kindia
# Processing Record 48 of Set 12 | cockburn town
# Processing Record 49 of Set 12 | luwuk
# Processing Record 50 of Set 12 | gorin
# Processing Record 1 of Set 13 | kaeo
# Processing Record 2 of Set 13 | abonnema
# Processing Record 3 of Set 13 | mahibadhoo
# Processing Record 4 of Set 13 | skovde
# City not found. Skipping...
# Processing Record 5 of Set 13 | portree
# Processing Record 6 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 13 | bereda
# Processing Record 8 of Set 13 | naze
# Processing Record 9 of Set 13 | salvador
# Processing Record 10 of Set 13 | ojinaga
# Processing Record 11 of Set 13 | den helder
# Processing Record 12 of Set 13 | mtsensk
# Processing Record 13 of Set 13 | los llanos de aridane
# Processing Record 14 of Set 13 | wagrowiec
# Processing Record 15 of Set 13 | zaltan
# Processing Record 16 of Set 13 | buta
# Processing Record 17 of Set 13 | malinovoye ozero
# Processing Record 18 of Set 13 | mogadishu
# Processing Record 19 of Set 13 | chaman
# Processing Record 20 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | aransas pass
# Processing Record 23 of Set 13 | rosetta
# Processing Record 24 of Set 13 | athabasca
# Processing Record 25 of Set 13 | kologriv
# Processing Record 26 of Set 13 | olga
# Processing Record 27 of Set 13 | anadyr
# Processing Record 28 of Set 13 | satrikh
# Processing Record 29 of Set 13 | santa maria da boa vista
# Processing Record 30 of Set 13 | trinidad
# Processing Record 31 of Set 13 | havre-saint-pierre
# Processing Record 32 of Set 13 | road town
# Processing Record 33 of Set 13 | byron bay
# Processing Record 34 of Set 13 | pilar
# Processing Record 35 of Set 13 | zatoka
# Processing Record 36 of Set 13 | saint-jean-de-luz
# Processing Record 37 of Set 13 | remedios
# Processing Record 38 of Set 13 | thomasville
# Processing Record 39 of Set 13 | sembakung
# Processing Record 40 of Set 13 | divnomorskoye
# Processing Record 41 of Set 13 | shakhtinsk
# Processing Record 42 of Set 13 | mokhsogollokh
# Processing Record 43 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 13 | abu dhabi
# Processing Record 45 of Set 13 | uyuni
# Processing Record 46 of Set 13 | alyangula
# Processing Record 47 of Set 13 | san rafael
# Processing Record 48 of Set 13 | kulhudhuffushi
# Processing Record 49 of Set 13 | mbaiki
# Processing Record 50 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 14 | kargasok
# Processing Record 2 of Set 14 | karaton
# Processing Record 3 of Set 14 | olinda
# Processing Record 4 of Set 14 | karratha
# Processing Record 5 of Set 14 | stephenville
# Processing Record 6 of Set 14 | lingyuan
# Processing Record 7 of Set 14 | bosaso
# Processing Record 8 of Set 14 | dera ghazi khan
# Processing Record 9 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 14 | poum
# Processing Record 11 of Set 14 | moranbah
# Processing Record 12 of Set 14 | chara
# Processing Record 13 of Set 14 | liverpool
# Processing Record 14 of Set 14 | warrington
# Processing Record 15 of Set 14 | lagos
# Processing Record 16 of Set 14 | kaupanger
# Processing Record 17 of Set 14 | biloxi
# Processing Record 18 of Set 14 | harper
# Processing Record 19 of Set 14 | beyneu
# Processing Record 20 of Set 14 | great falls
# Processing Record 21 of Set 14 | eydhafushi
# Processing Record 22 of Set 14 | dunmore town
# Processing Record 23 of Set 14 | tambopata
# Processing Record 24 of Set 14 | neryungri
# Processing Record 25 of Set 14 | birao
# Processing Record 26 of Set 14 | pafos
# Processing Record 27 of Set 14 | alta floresta
# Processing Record 28 of Set 14 | porto novo
# Processing Record 29 of Set 14 | sharjah
# Processing Record 30 of Set 14 | saryozek
# Processing Record 31 of Set 14 | bystryy istok
# Processing Record 32 of Set 14 | komsomolskiy
# Processing Record 33 of Set 14 | rameshki
# Processing Record 34 of Set 14 | jasper
# Processing Record 35 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 14 | rio gallegos
# Processing Record 37 of Set 14 | conakry
# Processing Record 38 of Set 14 | tocopilla
# Processing Record 39 of Set 14 | maputo
# Processing Record 40 of Set 14 | barabinsk
# Processing Record 41 of Set 14 | bonavista
# Processing Record 42 of Set 14 | erenhot
# Processing Record 43 of Set 14 | sangar
# Processing Record 44 of Set 14 | antofagasta
# Processing Record 45 of Set 14 | leshukonskoye
# Processing Record 46 of Set 14 | korla
# City not found. Skipping...
# Processing Record 47 of Set 14 | jasidih
# Processing Record 48 of Set 14 | gladstone
# Processing Record 49 of Set 14 | kachug
# Processing Record 50 of Set 14 | kakinada
# Processing Record 1 of Set 15 | phon
# Processing Record 2 of Set 15 | vacaria
# Processing Record 3 of Set 15 | pittsfield
# Processing Record 4 of Set 15 | campoverde
# Processing Record 5 of Set 15 | pundaguitan
# Processing Record 6 of Set 15 | chokwe
# Processing Record 7 of Set 15 | baherden
# Processing Record 8 of Set 15 | kaitangata
# Processing Record 9 of Set 15 | labuhan
# Processing Record 10 of Set 15 | sobolevo
# Processing Record 11 of Set 15 | vostok
# Processing Record 12 of Set 15 | tashtagol
# Processing Record 13 of Set 15 | henties bay
# Processing Record 14 of Set 15 | morro bay
# Processing Record 15 of Set 15 | arica
# Processing Record 16 of Set 15 | culebra
# Processing Record 17 of Set 15 | clive
# Processing Record 18 of Set 15 | ouargaye
# Processing Record 19 of Set 15 | gwadar
# Processing Record 20 of Set 15 | songea
# Processing Record 21 of Set 15 | bandrele
# Processing Record 22 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 23 of Set 15 | upington
# Processing Record 24 of Set 15 | culpeper
# Processing Record 25 of Set 15 | salalah
# Processing Record 26 of Set 15 | kahului
# Processing Record 27 of Set 15 | urumqi
# Processing Record 28 of Set 15 | van
# Processing Record 29 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 15 | sorong
# Processing Record 31 of Set 15 | birobidzhan
# Processing Record 32 of Set 15 | whitehorse
# Processing Record 33 of Set 15 | aranos
# Processing Record 34 of Set 15 | port blair
# Processing Record 35 of Set 15 | ust-ilimsk
# Processing Record 36 of Set 15 | akureyri
# Processing Record 37 of Set 15 | kharan
# Processing Record 38 of Set 15 | tuy hoa
# Processing Record 39 of Set 15 | marsa matruh
# Processing Record 40 of Set 15 | bismarck
# Processing Record 41 of Set 15 | anito
# Processing Record 42 of Set 15 | galle
# Processing Record 43 of Set 15 | berlevag
# Processing Record 44 of Set 15 | manaure
# Processing Record 45 of Set 15 | cartagena
# Processing Record 46 of Set 15 | gizo
# Processing Record 47 of Set 15 | soyo
# Processing Record 48 of Set 15 | padang
# Processing Record 49 of Set 15 | raudeberg
# Processing Record 50 of Set 15 | turukhansk
# Processing Record 1 of Set 16 | khovu-aksy
# Processing Record 2 of Set 16 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 16 | vila franca do campo
# Processing Record 4 of Set 16 | bilma
# Processing Record 5 of Set 16 | matamoros
# Processing Record 6 of Set 16 | la libertad
# Processing Record 7 of Set 16 | verkhnevilyuysk
# Processing Record 8 of Set 16 | etchojoa
# Processing Record 9 of Set 16 | vuktyl
# Processing Record 10 of Set 16 | kibuye
# Processing Record 11 of Set 16 | neokhorion
# Processing Record 12 of Set 16 | riyadh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Phan Thiet      VN  10.93  108.10     75.51        88         100
# 1       Cape Town      ZA -33.93   18.42     66.99        72           0
# 2      Georgetown      MY   5.41  100.34     78.80        88          40
# 3        Victoria      HK  22.29  114.16     75.00        71          90
# 4          Hobart      AU -42.88  147.33     64.00        72          75
# 5       Huichapan      MX  20.38  -99.65     71.60        28           5
# 6   Puerto Gaitan      CO   4.31  -72.08     74.52        91         100
# 7  Cap Malheureux      MU -19.98   57.61     66.99        69          46
# 8     New Norfolk      AU -42.78  147.06     64.00        66         100
# 9            Hilo      US  19.73 -155.09     84.20        62          90
#
#    Wind Speed Current Description
# 0        3.33   'overcast clouds'
# 1        8.05         'clear sky'
# 2        3.36  'scattered clouds'
# 3        7.49   'overcast clouds'
# 4        9.17     'broken clouds'
# 5       26.40         'clear sky'
# 6        6.29   'overcast clouds'
# 7        3.00  'scattered clouds'
# 8        1.01   'overcast clouds'
# 9        6.93   'overcast clouds'

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
